# %% [markdown]
# ## String Methods
# We can apply different functions to strings as we would do in Excel. However in Python we use methods. A method is a function that "belongs to" an object. To call a method we use the "." sign after the object .  Let's see some string methods to change the case of text.

# %%
# change case of text
print("Hello World".upper())
# Out:
# HELLO WORLD

# %%
# change case of text
print("Hello World".lower())
# Out:
# hello world

# %%
# change case of text
print("Hello World".title())
# Out:
# Hello World

# %%
# count letters
print("hello world".count('o'))
print("Rishi Rokde".count("R"))
# Out:
# 2
# 2

# %%
# replace string letters
print("String".replace('i', 'o'))
# Out:
# Strong

# %%
m1 ="I am Learning Python"

# %%
m2 = " and it's fun!"

# %%
m1
# Out:
# 'I am Learning Python'

# %%
m2
# Out:
# " and it's fun!"

# %%
m = m1 + m2

# %%
m
# Out:
# "I am Learning Python and it's fun!"

# %% [markdown]
# ## List
# In Python, lists are used to store multiple items in a single variable. Lists are ordered and mutable containers. In Python, we call 'mutable' to objects that can change their values. That is, elements within a list can change their value.
#
# To create a list, we have to introduce the elements inside square brackets ([]), separated by commas. Consider the following list named "countries" that contains some of the countries with the largest population around the world.

# %%
countries = ['United States', 'India', 'China', 'Brazil']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %% [markdown]
# ## Indexing
# By indexing we can obtain a list item or element by its position. Each item in a list has an index (position in the list). Python uses zero-based indexing. That is, the first element ("United States") has an index 0, the second("India") has index 1, and so on.
#
# To access an element by its index we need to use square brackets []. Let's see some examples:

# %%
print(countries[0])
# Out:
# United States

# %%
print(countries[2])
# Out:
# China

# %%
print(countries[1])
# Out:
# India

# %%
print(countries[-1])
# Out:
# Brazil

# %%
print(countries[-2])
# Out:
# China

# %% [markdown]
# # Slicing
# Slicing means accessing parts of a list.
# A slice is a subset of list elements.
# Slice notation takes the form of:
#
# list_name[start:stop]
#
# where "start" represents the index of the first element, and stop represents the element to stop at (without including it in the slice).
#
# Let's see some examples:

# %%
print(countries[0:3])
# Out:
# ['United States', 'India', 'China']

# %%
print(countries[0:])
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
print(countries[:4])
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
# append: Adds a new element at the end of a list
countries = ['United States', 'India', 'China', 'Brazil']
countries.append('Russia')
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Russia']

# %%
# append: Adds a new element at the end of a list
countries = ['United States', 'India', 'China', 'Brazil']
countries.insert(1,'Russia')
countries
# Out:
# ['United States', 'Russia', 'India', 'China', 'Brazil']

# %%
# joining lists using the + operators
countries_2 = ['UK', 'Germany', 'Austria']
countries + countries_2
# Out:
# ['United States',
#  'Russia',
#  'India',
#  'China',
#  'Brazil',
#  'UK',
#  'Germany',
#  'Austria']

# %%
# nested list
nested_list = [countries, countries_2]
nested_list
# Out:
# [['United States', 'Russia', 'India', 'China', 'Brazil'],
#  ['UK', 'Germany', 'Austria']]

# %%
countries = ['United States', 'India',
             'China', 'Brazil']
print(countries)
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
# .remove() Removes the first matching value
countries.remove('United States')

# %%
countries
# Out:
# ['India', 'China', 'Brazil']

# %%
countries.pop(1)
# Out:
# 'China'

# %%
countries
# Out:
# ['India', 'Brazil']

# %%
del countries[1]

# %%
countries
# Out:
# ['India']

# %% [markdown]
# # Sorting a list
# We can easily sort a list using the .sort() method. Let's create a new list called numbers and then sort it from the smallest to largest number.

# %%
numbers = [4, 3, 10, 7, 1, 2]
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers = [4, 3, 10, 7, 1, 2]
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
numbers[0] = 10
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
rishi =  countries[:]

# %%
rishi
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
rokde = countries.copy()

# %%
rokde
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
my_data = {'name':'Rishi', 'age':21}

# %%
my_data
# Out:
# {'name': 'Rishi', 'age': 21}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Rishi', 21])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Rishi'), ('age', 21)])

# %%
my_data['height']=1.7

# %%
my_data
# Out:
# {'name': 'Rishi', 'age': 21, 'height': 1.7}

# %%
my_data.update({'height':1.8,'languages':['English', 'marathi']})

# %%
my_data
# Out:
# {'name': 'Rishi',
#  'age': 21,
#  'height': 1.8,
#  'languages': ['English', 'marathi']}

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\Notes'

# %%
os.listdir()
# Out:
# ['.git',
#  'Day2.ipynb',
#  'practice.ipynb',
#  'Python Tutorial Full Notes - Faizan Khan.pdf',
#  'README.md',
#  'Rishi']

# %%
os.makedirs('Rishi')
