# %%
print("Hello World".upper())
# Out:
# HELLO WORLD

# %%
print("Hello World".lower())
# Out:
# hello world

# %%
print("Hello World".title())
# Out:
# Hello World

# %%
a=6
b=3
c=a*b
print(c)
# Out:
# 18

# %%
a=5
b=3
c=a+b
print(c)
# Out:
# 8

# %%
m1="i am learning python"
m2="and its fun"
m=m1+m2
m
# Out:
# 'i am learning pythonand its fun'

# %%
countries=['india','china','brazil']
countries
# Out:
# ['india', 'china', 'brazil']

# %%
print(countries[0])
print(countries[1])
print(countries[2])
# Out:
# india
# china
# brazil

# %%
countries=['india','china','bnrazil']
print(countries[0:3])
# Out:
# ['india', 'china', 'bnrazil']

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries.append('Canada')
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada']

# %%
countries = ['United States', 'India', 'China', 'Brazil']
countries.insert(0,'Canada')
countries
# Out:
# ['Canada', 'United States', 'India', 'China', 'Brazil']

# %%
#dictionary
my_data={'name':'Rishi','age':21}

# %%
my_data['name']
my_data.keys()
my_data.values()
# Out:
# dict_values(['Rishi', 21])

# %%
#if statement
age = 18

if age>=18:
    print("You're an adult!")
elif age>=13:
    print("You're a teenager!")
else:
    print("You're a kid")
# Out:
# You're an adult!

# %%
numbers = [4, 3, 10, 7, 1, 2]
numbers.sort()
numbers
# Out:
# [1, 2, 3, 4, 7, 10]

# %%
numbers[0]=1000
numbers
# Out:
# [1000, 7, 4, 3, 2, 1]

# %%
numbers=[4,3,10,7,1,2]
numbers.sort(reverse=True)
numbers
# Out:
# [10, 7, 4, 3, 2, 1]

# %%
def sum_values (a,b):
    x=a-b
    return x

# %%
sum_values (3,2)
# Out:
# 1

# %%
#if-elif-else 
score=85
if score>=90:
  print("Grade-A")
elif score>=80:
   print("Grade-B")
elif score>=70:
   print("Grade-c") 
else:
   print("Grade-D")
# Out:
# Grade-B

# %%
print("Hello World")
print
# Out:
# Hello World
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import os
os.getcwd()
# Out:
# 'd:\\Notes'
