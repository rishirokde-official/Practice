# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/rishirokde-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/05.Data%20Extraction/players_20.csv")

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df.set_index('short_name' , inplace=True)

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df=df[['long_name','age','dob','height_cm','weight_kg','nationality' , 'club']]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# sample()

# %%
# extract 10 random elements from the "nationality" column
df['nationality'].sample(10,random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. Chudý                Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
#extract 20% data from table
df.sample(frac=0.2,random_state=64)
# Out:
#                             long_name  age         dob  height_cm  weight_kg  \
# short_name
# J. Silva               Jonathan Silva   25  1994-06-29        178         72
# J. Müller          Jim-Patrick Müller   29  1989-08-04        182         75
# Raúl Sánchez     Raúl Sánchez Sánchez   21  1997-11-08        188         74
# V. Costache         Valentin Costache   20  1998-08-02        176         72
# A. Szymanowski  Alexander Szymanowski   30  1988-10-13        175         65
# ...                               ...  ...         ...        ...        ...
# J. Emmanuel           Joshua Emmanuel   21  1997-08-18        180         70
# O. Ademi                  Orhan Ademi   27  1991-10-28        189         85
# S. Berge                 Sander Berge   21  1998-02-18        195         94
# S. Piesinger          Simon Piesinger   27  1992-05-13        192         84
# J. Linnet                Jacob Linnet   24  1995-04-17        180         70
#
# ...

# %%
df.sample(frac=2, replace=True, random_state=99)
# Out:
#                                     long_name  age         dob  height_cm  \
# short_name
# M. Hauptmeijer               Mike Hauptmeijer   22  1997-03-18        191
# A. Mosquera                   Andrés Mosquera   29  1990-02-20        182
# V. Thill                        Vincent Thill   19  2000-02-04        172
# D. Bouanga                      Denis Bouanga   24  1994-11-11        180
# S. Al Selouli                 Saad Al Selouli   21  1998-05-25        168
# ...                                       ...  ...         ...        ...
# M. Connor                      Matthew Connor   22  1997-04-08        192
# J. Northcott                 Jordan Northcott   17  2002-02-09        162
# A. Bodzek                         Adam Bodzek   33  1985-09-07        184
# J. Adebayo-Smith         Jordan Adebayo-Smith   18  2001-01-11        181
# F. Mac Allister   Francis Manuel Mac Allister   23  1995-10-30        176
#
# ...
