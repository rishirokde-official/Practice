# %%
import pandas as pd

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/rishirokde-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/05.Data%20Extraction/players_20.csv")

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
if 'short_name' in df.columns:
    df.set_index('short_name',inplace=True)

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %% [markdown]
# Selecting with single value position

# %%
#get the height of messi
df.iloc[0,5]
# Out:
# np.int64(170)

# %%
#get the weight of neymar jr
df.iloc[2,6]
# Out:
# np.int64(68)

# %%
#get all rowws height of all player
df.iloc[:,5]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Neymar Jr            175
# J. Oblak             188
# E. Hazard            175
#                     ...
# Shao Shuai           186
# Xiao Mingjie         177
# Zhang Wei            186
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
#particular player info (neymar jr )
df.iloc[2,:]
# Out:
# sofifa_id                                                190871
# player_url    https://sofifa.com/player/190871/neymar-da-sil...
# long_name                         Neymar da Silva Santos Junior
# age                                                          27
# dob                                                  1992-02-05
#                                     ...
# lb                                                         61+3
# lcb                                                        46+3
# cb                                                         46+3
# rcb                                                        46+3
# rb                                                         61+3
# Name: Neymar Jr, Length: 103, dtype: object

# %%
#get all data of messi and neymar
df.iloc[[0,2]]
# Out:
#             sofifa_id                                         player_url  \
# short_name
# L. Messi       158023  https://sofifa.com/player/158023/lionel-messi/...
# Neymar Jr      190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
# Neymar Jr    Neymar da Silva Santos Junior   27  1992-02-05        175
#
#             weight_kg nationality                 club  overall  ...   lwb  \
# short_name                                                       ...
# L. Messi           72   Argentina         FC Barcelona       94  ...  68+2
# Neymar Jr          68      Brazil  Paris Saint-Germain       92  ...  66+3
#
#              ldm   cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# short_name
# L. Messi    66+2  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# ...

# %%
#get the height of messi and cr7
df.iloc[[0,1],5]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
#get the h and w of neymar
df.iloc[2,[5,6]]
# Out:
# height_cm    175
# weight_kg     68
# Name: Neymar Jr, dtype: object

# %%
#get height and weight of neymar  and messi
df.iloc[[0,2],[5,6]]
# Out:
#             height_cm  weight_kg
# short_name
# L. Messi          170         72
# Neymar Jr         175         68

# %% [markdown]
# Selecting a range of data with a slice

# %%
players=[0,2]
df.iloc[players,1:3]
# Out:
#                                                    player_url  \
# short_name
# L. Messi    https://sofifa.com/player/158023/lionel-messi/...
# Neymar Jr   https://sofifa.com/player/190871/neymar-da-sil...
#
#                                  long_name
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini
# Neymar Jr    Neymar da Silva Santos Junior

# %%
column=[1,2,3,4]
df.iloc[0:10,column]
# Out:
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# K. De Bruyne       https://sofifa.com/player/192985/kevin-de-bruy...
# M. ter Stegen      https://sofifa.com/player/192448/marc-andre-te...
# V. van Dijk        https://sofifa.com/player/203376/virgil-van-di...
# L. Modrić          https://sofifa.com/player/177003/luka-modric/2...
# M. Salah           https://sofifa.com/player/209331/mohamed-salah...
#
#                                              long_name  age         dob
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# ...

# %% [markdown]
# Selecting with conditions

# %%
#select player with heightabove 180 cm
column=[1,2,3,4]
df.iloc[list(df['height_cm']>180),column]
# Out:
#                                                           player_url  \
# short_name
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# K. De Bruyne       https://sofifa.com/player/192985/kevin-de-bruy...
# M. ter Stegen      https://sofifa.com/player/192448/marc-andre-te...
# V. van Dijk        https://sofifa.com/player/203376/virgil-van-di...
# ...                                                              ...
# P. Martin          https://sofifa.com/player/251789/paul-martin/2...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# Zhang Wei          https://sofifa.com/player/252332/wei-zhang/20/...
# Wang Haijian       https://sofifa.com/player/251110/haijian-wang/...
# Pan Ximing         https://sofifa.com/player/233449/ximing-pan/20...
#
#                                              long_name  age         dob
# short_name
# ...

# %%
#multiple conditions = from particular country
df.iloc[list((df['height_cm']>180)&(df['nationality']=='Argentina')), :]
# Out:
#                 sofifa_id                                         player_url  \
# short_name
# M. Icardi          201399  https://sofifa.com/player/201399/mauro-icardi/...
# G. Higuaín         167664  https://sofifa.com/player/167664/gonzalo-higua...
# E. Garay           170481  https://sofifa.com/player/170481/ezequiel-gara...
# N. Otamendi        192366  https://sofifa.com/player/192366/nicolas-otame...
# G. Rulli           215316  https://sofifa.com/player/215316/geronimo-rull...
# ...                   ...                                                ...
# T. Durso           240955  https://sofifa.com/player/240955/tomas-durso/2...
# J. Hass            247295  https://sofifa.com/player/247295/joaquin-hass/...
# R. Ferrario        245057  https://sofifa.com/player/245057/rafael-ferrar...
# L. Finochietto     241099  https://sofifa.com/player/241099/leandro-finoc...
# N. Forastiero      246841  https://sofifa.com/player/246841/nicolas-foras...
#
# ...
