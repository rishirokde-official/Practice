# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/rishirokde-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/05.Data%20Extraction/players_20.csv")

# %%
df
# Out:
#                    sofifa_id  \
# short_name
# L. Messi              158023
# Cristiano Ronaldo      20801
# Neymar Jr             190871
# J. Oblak              200389
# E. Hazard             183277
# ...                      ...
# Shao Shuai            245006
# Xiao Mingjie          250995
# Zhang Wei             252332
# Wang Haijian          251110
# Pan Ximing            233449
#
#                                                           player_url  \
# short_name
# L. Messi           https://sofifa.com/player/158023/lionel-messi/...
# Cristiano Ronaldo  https://sofifa.com/player/20801/c-ronaldo-dos-...
# Neymar Jr          https://sofifa.com/player/190871/neymar-da-sil...
# J. Oblak           https://sofifa.com/player/200389/jan-oblak/20/...
# E. Hazard          https://sofifa.com/player/183277/eden-hazard/2...
# ...                                                              ...
# Shao Shuai         https://sofifa.com/player/245006/shuai-shao/20...
# ...

# %%
df=df[['long_name','age','dob','height_cm','weight_kg','nationality','club']]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# Set value to one call

# %%
#update messi height
df.loc['L. Messi' , 'height'] = 175

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   0.0           0
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak   0.0           0
# E. Hazard                                  Eden Hazard   0.0           0
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅   0.0           0
# Xiao Mingjie                              Mingjie Xiao   0.0           0
# Zhang Wei                                           张威   0.0           0
# Wang Haijian                                       汪海健   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# Set value to entire column

# %%
#set height of all players =190
df.loc[: , 'height_cm'] = 190

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
#get all columns that is corresponding{matching , releaated} to player ranked last in fifa
df.iloc[-1 , :]
# Out:
# long_name      NaN
# age            NaN
# dob            NaN
# height_cm      NaN
# weight_kg      NaN
# nationality    NaN
# club           NaN
# height         NaN
# Name: Pan Ximing, dtype: object

# %%
import numpy as np

# %%
#set null values [0]
df.iloc[-1 , :]=np.nan

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   0.0           0
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak   0.0           0
# E. Hazard                                  Eden Hazard   0.0           0
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅   0.0           0
# Xiao Mingjie                              Mingjie Xiao   0.0           0
# Zhang Wei                                           张威   0.0           0
# Wang Haijian                                       汪海健   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# set value to multiple cells

# %%
df.loc[['L. Messi' , 'Neymar Jr'],['height_cm']] = 175

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak  26.0  1993-01-07
# E. Hazard                                  Eden Hazard  28.0  1991-01-07
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅  22.0  1997-03-10
# Xiao Mingjie                              Mingjie Xiao  22.0  1997-01-01
# Zhang Wei                                           张威  19.0  2000-05-16
# Wang Haijian                                       汪海健  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# Set value to row matching condition

# %%
columns=[
    'age',
    'dob',
    'height_cm',
    'weight_kg'

]
df.loc[df['height_cm']>180,columns]=0

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   0.0           0
# Neymar Jr                Neymar da Silva Santos Junior  27.0  1992-02-05
# J. Oblak                                     Jan Oblak   0.0           0
# E. Hazard                                  Eden Hazard   0.0           0
# ...                                                ...   ...         ...
# Shao Shuai                                          邵帅   0.0           0
# Xiao Mingjie                              Mingjie Xiao   0.0           0
# Zhang Wei                                           张威   0.0           0
# Wang Haijian                                       汪海健   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...
