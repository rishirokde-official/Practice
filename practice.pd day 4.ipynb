# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

# %%
uploded=files.upload()
# Out:
#      <input type="file" id="files-20f4fd0f-ccd9-41cb-92ff-066ecb82c83f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20f4fd0f-ccd9-41cb-92ff-066ecb82c83f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("/content/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.head(11)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 1   female        group C                some college      standard
# 2   female        group B             master's degree      standard
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 5   female        group B          associate's degree      standard
# 6   female        group B                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 9   female        group B                 high school  free/reduced
# 10    male        group C          associate's degree      standard
#
#    test preparation course  math score  reading score  writing score
# 0                     none          72             72             74
# ...

# %%
df.tail(11)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.shape
# Out:
# (1000, 8)

# %%
pd.set_option('display.max_rows',1000)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
max(df.index)
# Out:
# 999

# %%
min(df.index)
# Out:
# 0

# %%
len(df)
# Out:
# 1000

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#finding particular column
df['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
type(df['gender'])
# Out:
# pandas.core.series.Series

# %%
df['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df['gender'].head(11)
# Out:
# 0     female
# 1     female
# 2     female
# 3       male
# 4       male
# 5     female
# 6     female
# 7       male
# 8       male
# 9     female
# 10      male
# Name: gender, dtype: object

# %%
df.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
#selecting teo or more column
#using[[]]
df[['gender','math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# 5    female          71
# 6    female          88
# 7      male          40
# 8      male          64
# 9    female          38
# 10     male          58
# 11     male          40
# 12   female          65
# 13     male          78
# 14   female          50
# 15   female          69
# 16     male          88
# 17   female          18
# 18     male          46
# 19   female          54
# 20     male          66
# 21   female          65
# 22     male          44
# 23   female          69
# 24     male          74
# 25     male          73
# 26     male          69
# 27   female          67
# 28     male          70
# 29   female          62
# 30   female          69
# 31   female          63
# 32   female          56
# 33     male          40
# 34     male          97
# 35     male          81
# 36   female          74
# ...

# %%
type([['gender','math score']])
# Out:
# list

# %%
#selecting multiple columns
df[['gender','math score','reading score','writing score','race/ethnicity']]
# Out:
#      gender  math score  reading score  writing score race/ethnicity
# 0    female          72             72             74        group B
# 1    female          69             90             88        group C
# 2    female          90             95             93        group B
# 3      male          47             57             44        group A
# 4      male          76             78             75        group C
# 5    female          71             83             78        group B
# 6    female          88             95             92        group B
# 7      male          40             43             39        group B
# 8      male          64             64             67        group D
# 9    female          38             60             50        group B
# 10     male          58             54             52        group C
# 11     male          40             52             43        group D
# 12   female          65             81             73        group B
# ...

# %%
#adding new column in a table
df['language score']=90

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
#adding new column with an array
import numpy as np

# %%
language_score=np.arange(0,1000)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
len(language_score)
# Out:
# 1000

# %%
df['language score']=language_score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
init_language_score=np.random.randint(1,100,size=1000)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df['language score']=init_language_score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...
