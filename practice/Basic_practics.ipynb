# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/rishirokde-official/Python-for-Data-Science/refs/heads/main/python-for-data-science-main/02.Intro%20to%20Pandas/StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %%
df.tail(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.shape
# Out:
# (1000, 8)

# %%
pd.set_option('display.max_rows',100)

# %% [markdown]
# Basic attribute , methods and functions

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Functions

# %%
len(df)
# Out:
# 1000

# %%
max(df.index)
# Out:
# 999

# %%
min(df.index)
# Out:
# 0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df,2).head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88

# %% [markdown]
# selecting one column

# %%
df['gender']
df['gender'].index
df['gender'].head(2)
# Out:
# 0    female
# 1    female
# Name: gender, dtype: object

# %%
df["math score"].head(1)
# Out:
# 0    72
# Name: math score, dtype: int64

# %% [markdown]
# Selecting two or more columns

# %%
df[['gender','math score','writing score','reading score']].head(1)
# Out:
#    gender  math score  writing score  reading score
# 0  female          72             74             72

# %%
df['language score']=70

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    language score  average
# 0               0      218
# 1               1      247

# %% [markdown]
# Adding a new column with an array

# %%
import numpy as np

# %%
language_score=np.arange(0,1000)

# %%
len(language_score)
# Out:
# 1000

# %%
df['language score']=language_score

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    language score  average
# 0               0      218
# 1               1      247

# %% [markdown]
# Math Operations

# %%
df['math score'].sum()
df['math score'].count()
df['math score'].mean()
df['math score'].max()
df['math score'].min()
df['math score'].std()
# Out:
# 15.163080096009468

# %% [markdown]
# Operations in rows

# %%
df['math score']+df['reading score']+df['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df['average']=df['math score']+df['reading score']+df['writing score']

# %%
df.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    language score  average
# 0               0      218
# 1               1      247

# %% [markdown]
# value counts()

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %% [markdown]
# sorting

# %%
df.sort_values('math score',ascending=False).head(2)
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 451  female        group E                some college  standard
# 458  female        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score  \
# 451                    none         100             92             97
# 458                    none         100            100            100
#
#      language score  average
# 451             451      289
# 458             458      300
